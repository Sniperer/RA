# %%
# !pip install matplotlib

# %% [markdown]
# # Plot for exercise 4\&5

# %%
import matplotlib.pyplot as plt
#plt.figure(1)
#plt.subplot(221)
x = ['sketch','hash with chaining']
y1 = [3.0522e-08,2.445e-09]
#y2 = []
#y3 = []
plt.bar(x,y1)
#plt.plot(x,y2)
#plt.plot(x,y3)
plt.title("Average Measure Time")
plt.xlabel("different data structure")
plt.ylabel("Time (s)")
plt.show()

# %% [markdown]
# # Plot for exercise 6\&7

# %%
import math
import random
#plt.subplot(222)
x = [i for i in range(6,29)]
#y1 = [random.randint(100,1000) for i in range(6,29)]# hash with chaining
#y2 = [random.randint(100,1000) for i in range(6,29)]# sketch with r=2**7
#y3 = [random.randint(100,1000) for i in range(6,29)]# sketch with r=2**10
#y4 = [random.randint(100,1000) for i in range(6,29)]# sketch with r=2**20
y1=[1.18136,1.27742,1.23208,1.21615,1.2199,1.23854,6.90988,7.18589,7.16206,7.17476,9.25968,7.32561,11.2921,18.3723,21.8332,20.508,21.2096,22.1596,26.0112,1282.71,1164.2,1173.69,1273.94]
y2=[5.76109,5.97586,6.15944,5.89314,5.90959,5.89041,6.20785,6.13917,6.6149,7.55996,8.62211,9.13484,9.22873,7.61236,8.30524,8.35392,9.30142,8.7689,7.91134,8.96837,7.98551,8.84985,8.72308]
y3=[5.76109,6.04535,6.02832,5.90339,5.86299,5.9915,5.90076,6.13082,6.57726,7.59588,8.63747,9.30613,9.38704,9.27858,8.90324,8.84145,9.16142,8.78679,9.1381,8.84936,8.15739,8.83726,8.40843]
y4=[6.19846,6.11899,6.10722,6.01025,6.07576,6.05937,6.11471,6.63253,7.8253,8.56556,8.95078,9.82856,10.193,10.1325,10.3261,9.44674,9.99725,8.96061,8.98346,9.57162,9.53136,9.43462,9.54481]
"""
for i in range(20):
    y1.append(rs[i]['perfect']['query']/2**(rs[i]['case']))
    y2.append(rs[i]['hash']['query']/2**(rs[i]['case']))
    y3.append(rs[i]['tree']['query']/2**(rs[i]['case']))
"""
plt.plot(x,y1,label='hash with chaining')
plt.plot(x,y2,label='sketch 2^7')
plt.plot(x,y3,label='sketch 2^10')
plt.plot(x,y4,label='sketch 2^20')
plt.title("Average Update Time")
plt.xlabel("log2 n")
plt.ylabel("Time (s)")
plt.xticks(x)
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.subplot(121)
plt.plot(x,y2,label='sketch 2^7')
plt.plot(x,y3,label='sketch 2^10')
plt.plot(x,y4,label='sketch 2^20')
plt.title("Average Update Time for Sketch")
plt.xlabel("log2 n")
plt.ylabel("Time (s)")
plt.xticks(x)
plt.legend(loc=2)
plt.subplot(122)
plt.plot(x,y1,label="hash with chaining")
plt.xticks(x)
plt.title("Average Update Time for Hash with Chaining")
plt.xlabel("log2 n")
plt.ylabel("Time (s)")
plt.show()

# %% [markdown]
# # Plot for exercise 8

# %%
x = [i for i in range(3,21)]
#y = [random.randint(1,100) for i in range(3,21)]
#y = [0.737709, 0.346108, 0.116749, 0.110951, 0.101426, 0.132222, 0.0672243, 0.00394761, 0.0188901, 0.0260697, 0.0318187, 0.00225975, 0.00231069, 0.000570048, 0.00628309, 0.00190715, 0, 0]
y1 = [0.374455, 0.273873, 0.200055, 0.142793, 0.100857, 0.0734011, 0.0473529, 0.0337849, 0.0247151, 0.0180022, 0.0130595, 0.00894517, 0.00614511, 0.00416905, 0.00271518, 0.00162094, 0.000828293, 0.00050264, ]
plt.plot(x,y1,label='average relative error')
#plt.legend(loc=2)
plt.xticks(x)
plt.title('Average Relative Error of the Sketch')
plt.xlabel('log2 r')
plt.ylabel('Average Relative Error')
plt.show()

# %% [markdown]
# # Plot for exercise 9

# %%
#plt.figure(figsize=(16,8))
#plt.subplot(121)
x = [i for i in range(3,21)]
#y = [random.randint(1,100) for i in range(3,21)]
y2 = [1.61633, 1.49166, 1.49839, 1.22303, 0.984038, 0.839653, 0.497997, 0.238796, 0.113235, 0.0681455, 0.0472704, 0.0152548, 0.00508709, 0.00697906, 0.00256742, 0.000399967, 0, 0]
plt.plot(x,y2,label='average relative error')
#plt.legend(loc=2)
plt.xticks(x)
plt.title('Average Relative Error of the Sketch when Hash Func changes')
plt.xlabel('log2 r')
plt.ylabel('Average Relative Error')
#plt.show()
#plt.subplot(122)
# Out:
# Text(0, 0.5, 'Average Relative Error')

# %%
plt.plot(x,y1,label='4-wise')
plt.plot(x,y2,label='2-wise')
#plt.legend(loc=2)
plt.xticks(x)
plt.title('Average Relative Error of the Sketch with different hash function')
plt.xlabel('log2 r')
plt.ylabel('Average Relative Error')
plt.legend()
plt.show()
